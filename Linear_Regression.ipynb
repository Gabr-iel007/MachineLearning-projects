# %% [markdown]
# <a href="https://colab.research.google.com/github/Gabr-iel007/MachineLearning-projects/blob/main/Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
df = pd.read_csv('/advertising.csv')

# %%
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
df.tail()
# Out:
#         TV  Radio  Newspaper  Sales
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4

# %%
X = df[['TV']]
Y = df[['Sales']]

# %%
plt.figure(figsize=(8,5))
plt.scatter(df['TV'], df['Sales'])
plt.title('TV Advertising vs Sales')
plt.xlabel('TV Advertising')
plt.ylabel('Sales')

plt.show()

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

model = LinearRegression()
model.fit(X_train, Y_train)

print(model.coef_) #slope
print(model.intercept_) #intercept
# Out:
# [[0.05548294]]
# [7.00710843]

# %%
budgets = np.array((50,100,150,250)).reshape(-1,1)
sales_pred = model.predict(budgets)

print(sales_pred)
# Out:
# [[ 9.78125562]
#  [12.55540282]
#  [15.32955002]
#  [20.87784441]]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# visualize regression line

# %%
plt.figure(figsize=(8,5))
plt.scatter(X,Y)

plt.plot(
    X,
    model.predict(X),
    linewidth=2
)

plt.xlabel("TV Advertising Budget")
plt.ylabel("Sales")
plt.title("Linear Regression Line")

plt.show()
