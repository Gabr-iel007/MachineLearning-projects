# %% [markdown]
# <a href="https://colab.research.google.com/github/Gabr-iel007/MachineLearning-projects/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Linear Regression

# %%
import matplotlib.pyplot as plt

hours = [1,2,3,4,5]
score = [40,50,60,70,80]

plt.scatter(hours,score)
plt.xlabel("Hours Studied")
plt.ylabel("Score")
plt.title("Study Hours vs Exam Score")
plt.show()

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

X = np.array([1,2,3,4,5]).reshape(-1,1)
y = np.array([40,50,60,70,80])

model = LinearRegression()

model.fit(X,y)

prediction = model.predict([[6]])
print(prediction)
# Out:
# [90.]

# %%
from sklearn.metrics import r2_score

predictions = model.predict(X)
print(r2_score(y,predictions))
# Out:
# 1.0
