# %% [markdown]
# <a href="https://colab.research.google.com/github/Gabr-iel007/MachineLearning-projects/blob/main/DataPreprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Data Preprocessing
# - explain the importance of data preprocessing
# - identify common data quality issues
# - Encoding
# - feature scaling
# - normalization and standardization
# - splitting and training datasets

# %% [markdown]
# Data preprocessing is the process of transferring raw data into a clean and usable format before training a machine training model.
#
# workflow: -> raw data - data cleaning - handle missing values - resolve duplicates - encoding - feature scaling - train/test split - build machine learning model

# %% [markdown]
# Encoding categorical variables
# label encoding - convert categories to numbers (useful for binary categories)
# male/female - gender 1/0
#
# one hot encoding - city [lagos, ibadan, abuja] (multiple categories)
#    1      0        0
#    0      1        0
#    0      0        1

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()

df["Gender"] = encoder.fit_transform(df["Gender"])

# %% [markdown]
# Feature Scaling - helps to
# create values that are within smaller ranges
#
# withoout scalling, data training would be slow
# Biased learning
#
# Normalization - scale data between 0 and 1 more like standard deviation, Good for Neural networks, Sensitive to outliers
# Standardization - mean deviation,mean = 0
# Good for most ML models
# Less sensitive outliers
#
#
#
# Train/Test Split
#
# train data - is used to train the model
# test data - is used to evaluate the model
#
# 0.8 - Train
# 0.2 - Test
#
# 0.7 - Train
# 0.3 - Test
#
# randome state = 42
