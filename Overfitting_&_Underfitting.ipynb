# %% [markdown]
# <a href="https://colab.research.google.com/github/Gabr-iel007/MachineLearning-projects/blob/main/Overfitting_%26_Underfitting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Generalization is the ability of a machine learning model to perform well on data it has never seen before.
#
# Generalization is the true measure of a successful model
#
#
# Training error vs testing error
#
# Training error - measures how well the model performs on the data it learned from
#
# Testing error - measures how well the model performs on completely new data

# %% [markdown]
# Overfitting
#
# Good fit
#
# Underfitting
#
#
# Underfitting - this occurs when a model is too simple to learn the important patterns in the data

# %% [markdown]
# Generalization is the ability to perform well on a project it has never seen before
#
#
# Training error - measures how well the model performs on the data it learned from
#
# Testing error - measures how well the model performs on completely new data
#
# Underfitting - this occurs when a model is too simple to learn the important patterns in the data this occurs when the data is too robust for the model
#
#
# Generalization is more important because it lets us know a model is not strong enough to learn and execute robust data
#
#           Underfitting
#
# .Oversimplified model
# .Insufficient training
# .Lack of relevant features
#
#           Overfitting
# .Noise in the data
# .Data Leakage
# .Limited Training
#
# A model achieves 99% training accuracy and 62% testing accuracy. What problem does it have? How would you improve it
#
# The model is not Generalized enough, if there are new data it has never been trained on before it would'nt perform well
#
# I would use more and better data, clean noisy data and implement data augumentation
