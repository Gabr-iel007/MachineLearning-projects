# %% [markdown]
# <a href="https://colab.research.google.com/github/Gabr-iel007/MachineLearning-projects/blob/main/Task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd


data = {
    "StudentID": [101, 102, 103, 104, 105, 106, 107, 108, 109, 110, 111, 112, 113, 114, 115],
    "Name": ["Ayo", "Tolu", "James", "Aisha", "David", "Ayo", "Grace", "NaN", "Samuel", "Tolu", "Emeka", "Zara", "Daniel", "Peace", "Favour"],
    "Age": [18, 19, "NaN", 20, 21, 18, 22, 20, 19, 19, "NaN", 21, 20, 19, "NaN"],
    "Gender":["Male", "Female", "Male", "Female", "Male", "Male", "Female", "Female", "Male", "Female", "Male", "Female", "Male", "Female", "Female"],
    "Course": ["Python", "Data Science", "Python", "Machine Learning", "Python", "Python", "Data Science", "Python", "Data Science", "Data Science", "Python", "NaN", "Python", "Machine Learning", "Python"],
    "Score": [85, 92, 78, 50, 65, 85, 88, 75, 91, 92, 70, 89, 150, 82, 76],
    "Attendance": [90, 95, 88, 85, 65, 90, 92, 80, 94, 95, 85, 91, 87, 101, 89]
}

df = pd.DataFrame(data)

print(df)
# Out:
#     StudentID    Name  Age  Gender            Course  Score  Attendance
# 0         101     Ayo   18    Male            Python     85          90
# 1         102    Tolu   19  Female      Data Science     92          95
# 2         103   James  NaN    Male            Python     78          88
# 3         104   Aisha   20  Female  Machine Learning     50          85
# 4         105   David   21    Male            Python     65          65
# 5         106     Ayo   18    Male            Python     85          90
# 6         107   Grace   22  Female      Data Science     88          92
# 7         108     NaN   20  Female            Python     75          80
# 8         109  Samuel   19    Male      Data Science     91          94
# 9         110    Tolu   19  Female      Data Science     92          95
# 10        111   Emeka  NaN    Male            Python     70          85
# 11        112    Zara   21  Female               NaN     89          91
# ...

# %%
print(df[df["Score"]>(100)])
# Out:
#     StudentID    Name Age Gender  Course  Score  Attendance
# 12        113  Daniel  20   Male  Python    150          87

# %%
print(df[df["Attendance"]>100])
# Out:
#     StudentID   Name Age  Gender            Course Score  Attendance
# 13        114  Peace  19  Female  Machine Learning    82         101
